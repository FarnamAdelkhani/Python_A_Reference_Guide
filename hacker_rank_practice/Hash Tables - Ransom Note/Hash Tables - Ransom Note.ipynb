# %% [markdown]
# ![merge-the-tools.jpg](attachment:merge-the-tools.jpg)

# %% [markdown]
# ### Hash Tables: Ransom Note:
# <pre>
#
# Harold is a kidnapper who wants to write a ransom note.
# - The words in his note are case-sensitive
# - He must use only whole words available in the magazine.
#  ... He cannot use substrings or concatenation to create the words he needs.
#
# Given: the words in the magazine and the words in the ransom note
#     print Yes if he can replicate his ransom note exactly using whole words from the magazine
#     otherwise, print No.
#
# In case of a case-mismatch, the answer is no.
#     Example: Desired "Hashing" but only "hashing" is available.
#
#  -- Function Description --
#
# checkMagazine has the following parameters:
#     magazine: an array of strings, each a word in the magazine
#     note: an array of strings, each a word in the ransom note
#
#  --  Input Format --
#
# The first line contains two space-separated integers,  and , the numbers of words in the  and the ..
# The second line contains  space-separated strings, each .
# The third line contains  space-separated strings, each .
#
#  -- Constraints --
#
# .
# Each word consists of English alphabetic letters (i.e.,  to  and  to ).
# Output Format
#
# Print Yes if he can use the magazine to create an untraceable replica of his ransom note. Otherwise, print No.
#
#  -- Output Format --
#
# Print Yes if he can use the magazine to create an untraceable replica of his ransom note. Otherwise, print No.
#       </pre>
